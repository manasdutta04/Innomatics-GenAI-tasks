# %% [markdown]
# # Logic Building Task – 1

# %% [markdown]
# ## 1. User Login Check
# ### Problem Statement:
# Given a username and password, check whether login is successful.
# username = "admin"
# password = "1234"
#
# ### Requirements:
# Print "Login Successful" if both username and password match
# Otherwise print "Invalid Credentials"
# Real-World Application: Authentication systems

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == 'admin' and password == '1234':
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successful

# %% [markdown]
# ## 2. Pass / Fail Analyzer
# ### Problem Statement:
# Analyze student results.
# marks = [45, 78, 90, 33, 60]
#
# ### Requirements:
# A student passes if marks ≥ 50
# Count the total number of pass students
# Count the total number of fail students
# Print the final result clearly
# Real-World Application: Academic evaluation systems

# %%
marks = [45, 78, 90, 33, 60, 85, 20, 65, 70, 50]

passing_students = 0
failing_students = 0

print("--- Individual Student Results ---")
for mark in marks:
    if mark >= 50:
        print(f"Student with mark {mark}: Pass")
        passing_students += 1
    else:
        print(f"Student with mark {mark}: Fail")
        failing_students += 1

print("\n--- Summary ---")
print(f"Total Passing Students: {passing_students}")
print(f"Total Failing Students: {failing_students}")
# Out:
# --- Individual Student Results ---
# Student with mark 45: Fail
# Student with mark 78: Pass
# Student with mark 90: Pass
# Student with mark 33: Fail
# Student with mark 60: Pass
# Student with mark 85: Pass
# Student with mark 20: Fail
# Student with mark 65: Pass
# Student with mark 70: Pass
# Student with mark 50: Pass
#
# --- Summary ---
# Total Passing Students: 7
# Total Failing Students: 3

# %% [markdown]
# ## 3. Simple Data Cleaner
# ### Problem Statement:
# Clean and standardize user names.
# names = [" Alice ", "bob", " CHARLIE "]
#
# ### Requirements:
# Remove extra spaces
# Convert all names to lowercase
# Print the cleaned list
# Real-World Application: Data preprocessing before analysis

# %%
names = [' Alice ', 'bob', ' CHARLIE ', '  DAVID  ']
cleaned_names = []

for name in names:
    cleaned_name = name.strip().lower()
    cleaned_names.append(cleaned_name)

print("Original names:", names)
print("Cleaned names:", cleaned_names)
# Out:
# Original names: [' Alice ', 'bob', ' CHARLIE ', '  DAVID  ']
# Cleaned names: ['alice', 'bob', 'charlie', 'david']

# %% [markdown]
# ## 4. Message Length Analyzer
# ### Problem Statement:
# Analyze message sizes.
# messages = ["Hi", "Welcome to the platform", "OK"]
#
# ### Requirements:
# Print the length of each message
# Flag messages longer than 10 characters
# Real-World Application: Text filtering and validation systems

# %%
messages = ['Hi', 'Welcome to the platform', 'OK', 'Another short one', 'This is a much longer message.']

print("--- Message Length Analysis ---")
for message in messages:
    length = len(message)
    print(f"Message: '{message}' (Length: {length})")
    if length > 10:
        print("  -> This message is long!")
# Out:
# --- Message Length Analysis ---
# Message: 'Hi' (Length: 2)
# Message: 'Welcome to the platform' (Length: 23)
#   -> This message is long!
# Message: 'OK' (Length: 2)
# Message: 'Another short one' (Length: 17)
#   -> This message is long!
# Message: 'This is a much longer message.' (Length: 30)
#   -> This message is long!

# %% [markdown]
# ## 5. Error Message Detector
# ### Problem Statement:
# Detect error messages from system logs.
# logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#
# ### Requirements:
# Count the number of "ERROR" entries
# Print the total error count
# Real-World Application: Monitoring and log analysis systems

# %%
logs = ['INFO', 'ERROR', 'WARNING', 'ERROR', 'DEBUG', 'ERROR', 'CRITICAL', 'ERROR', 'INFO']

error_count = 0

print("--- Error Message Detector ---")
for log_message in logs:
    if log_message == 'ERROR':
        error_count += 1
        print(f"Found an ERROR: {log_message}")
    else:
        print(f"Skipping log: {log_message}")

print(f"\nTotal 'ERROR' messages found: {error_count}")
# Out:
# --- Error Message Detector ---
# Skipping log: INFO
# Found an ERROR: ERROR
# Skipping log: WARNING
# Found an ERROR: ERROR
# Skipping log: DEBUG
# Found an ERROR: ERROR
# Skipping log: CRITICAL
# Found an ERROR: ERROR
# Skipping log: INFO
#
# Total 'ERROR' messages found: 4
